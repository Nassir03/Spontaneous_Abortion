# %% [markdown]
# <a href="https://colab.research.google.com/github/Nassir03/Spontaneous_Abortion/blob/main/Spontaneous_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Nassir03/Spontaneous_Abortion.git
# Out:
# Cloning into 'Spontaneous_Abortion'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m "New commit message"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
